# %% [raw]
# # Links
#
# https://registry.opendata.aws/nasa-power/
# https://nasa-power.s3.us-west-2.amazonaws.com/index.html
# https://power.larc.nasa.gov/docs/tutorials/service-data-request/aws/
#
# https://power.larc.nasa.gov/docs/

# %%
import os
import fsspec
import xarray as xr
import pandas as pd

from datetime import datetime

# %% [markdown]
# ### Remotely Connect via Python

# %%
# filepath = 'https://nasa-power.s3.amazonaws.com/syn1deg/temporal/power_syn1deg_monthly_temporal_lst.zarr'
filepath = 'https://nasa-power.s3.amazonaws.com/syn1deg/temporal/power_syn1deg_daily_temporal_utc.zarr'

filepath_mapped = fsspec.get_mapper(filepath)

ds = xr.open_zarr(store=filepath_mapped, consolidated=True)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                      (time: 10593, lat: 180, lon: 360)
# Coordinates:
#   * lat                          (lat) float64 -89.5 -88.5 -87.5 ... 88.5 89.5
#   * lon                          (lon) float64 -179.5 -178.5 ... 178.5 179.5
#   * time                         (time) datetime64[ns] 2000-12-31 ... 2029-12-31
# Data variables: (12/47)
#     AIRMASS                      (time, lat, lon) float32 dask.array<chunksize=(4000, 10, 15), meta=np.ndarray>
#     ALLSKY_KT                    (time, lat, lon) float32 dask.array<chunksize=(4000, 10, 15), meta=np.ndarray>
#     ALLSKY_NKT                   (time, lat, lon) float32 dask.array<chunksize=(4000, 10, 15), meta=np.ndarray>
#     ALLSKY_SFC_LW_DWN            (time, lat, lon) float32 dask.array<chunksize=(4000, 10, 15), meta=np.ndarray>
#     ALLSKY_SFC_LW_UP             (time, lat, lon) float32 dask.array<chunksize=(4000, 10, 15), meta=np.ndarray>
#     ALLSKY_SFC_PAR_DIFF          (time, lat, lon) float32 dask.array<chunksize=(4000, 10, 15), meta=np.ndarray>
#     ...                           ...
#     PSH                          (time, lat, lon) float32 dask.array<chunksize=(4000, 10, 15), meta=np.ndarray>
#     PW                           (time, lat, lon) float32 dask.array<chunksize=(4000, 10, 15), meta=np.ndarray>
#     SRF_ALB_ADJ                  (time, lat, lon) float32 dask.array<chunksize=(4000, 10, 15), meta=np.ndarray>
#     TOA_SW_DNI                   (time, lat, lon) float32 dask.array<chunksize=(4000, 10, 15), meta=np.ndarray>
#     TOA_SW_DWN                   (time, lat, lon) float32 dask.array<chunksize=(4000, 10, 15), meta=np.ndarray>
#     TS_ADJ                       (time, lat, lon) float32 dask.array<chunksize=(4000, 10, 15), meta=np.ndarray>
# Attributes: (12/37)
#     acknowledgement:            The Prediction of Worldwide Energy Resources ...
#     comment:                    POWER data version 10.0.0 uses the source dat...
#     conventions:                CF-1.8, ACDD-1.3
#     creator_email:              bradley.macpherson@nasa.gov
#     creator_name:               Bradley Macpherson
#     date_created:               2024-06-05T13:00:38Z
#     ...                         ...
#     time_coverage_end:          2029-12-31T00:00:00
#     time_coverage_resolution:   P1D
#     time_coverage_start:        2000-12-31T00:00:00
#     time_standard:              Universal Time Coordinated (UTC)
#     title:                      POWER Universal Time Coordinated (UTC) Time S...
#     version:                    POWER Version 10.0.0

# %%
ds.sel(
    lat=slice(35, 45),
    lon=slice(-85, -75),
    time=slice(datetime(2025, 10, 1), datetime(2025, 10, 31)),
    # method='nearest',
    # freq='1D',
).load()
# Out:
# <xarray.Dataset>
# Dimensions:                      (time: 31, lat: 10, lon: 10)
# Coordinates:
#   * lat                          (lat) float64 35.5 36.5 37.5 ... 42.5 43.5 44.5
#   * lon                          (lon) float64 -84.5 -83.5 -82.5 ... -76.5 -75.5
#   * time                         (time) datetime64[ns] 2025-10-01 ... 2025-10-31
# Data variables: (12/47)
#     AIRMASS                      (time, lat, lon) float32 nan nan ... nan nan
#     ALLSKY_KT                    (time, lat, lon) float32 nan nan ... nan nan
#     ALLSKY_NKT                   (time, lat, lon) float32 nan nan ... nan nan
#     ALLSKY_SFC_LW_DWN            (time, lat, lon) float32 nan nan ... nan nan
#     ALLSKY_SFC_LW_UP             (time, lat, lon) float32 nan nan ... nan nan
#     ALLSKY_SFC_PAR_DIFF          (time, lat, lon) float32 nan nan ... nan nan
#     ...                           ...
#     PSH                          (time, lat, lon) float32 nan nan ... nan nan
#     PW                           (time, lat, lon) float32 nan nan ... nan nan
#     SRF_ALB_ADJ                  (time, lat, lon) float32 nan nan ... nan nan
#     TOA_SW_DNI                   (time, lat, lon) float32 nan nan ... nan nan
#     TOA_SW_DWN                   (time, lat, lon) float32 nan nan ... nan nan
#     TS_ADJ                       (time, lat, lon) float32 nan nan ... nan nan
# Attributes: (12/37)
#     acknowledgement:            The Prediction of Worldwide Energy Resources ...
#     comment:                    POWER data version 10.0.0 uses the source dat...
#     conventions:                CF-1.8, ACDD-1.3
#     creator_email:              bradley.macpherson@nasa.gov
#     creator_name:               Bradley Macpherson
#     date_created:               2024-06-05T13:00:38Z
#     ...                         ...
#     time_coverage_end:          2029-12-31T00:00:00
#     time_coverage_resolution:   P1D
#     time_coverage_start:        2000-12-31T00:00:00
#     time_standard:              Universal Time Coordinated (UTC)
#     title:                      POWER Universal Time Coordinated (UTC) Time S...
#     version:                    POWER Version 10.0.0

# %% [markdown]
# ### Data Download

# %%
filepath = 'https://nasa-power.s3.us-west-2.amazonaws.com/syn1deg/temporal/power_syn1deg_monthly_temporal_lst.zarr'
filepath_mapped = fsspec.get_mapper(filepath)

ds = xr.open_zarr(filepath_mapped, consolidated=True)

# %%
# different ways to slice the data
ds_single_point = ds.ALLSKY_SFC_LW_DWN.sel(lat=39, lon=-77, method='nearest').load()
ds_single_time = ds.ALLSKY_SFC_LW_DWN.sel(time=datetime(2022, 12, 31)).load()
ds_time_series = ds.ALLSKY_SFC_LW_DWN.sel(time=pd.date_range(datetime(2019, 12, 31), datetime(2020, 12, 31), freq='1Y')).load()
ds_region = ds.ALLSKY_SFC_LW_DWN.sel(lat=slice(35, 45), lon=slice(-85, -75)).load()

# %%
# output = r'' # if none the location of the script is where the files will be outputted.

# export region as NetCDF4
# ds_region.to_netcdf(path=os.path.join(output, "region.nc"))

# %%
# export as CSV
# df_region = ds_region.to_dataframe()
# df_region.to_csv(os.path.join(output, "region.csv"))
